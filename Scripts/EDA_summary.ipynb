# %%
# Add the dependencies.
import pandas as pd
import os

# %%
#  Import data

FT_data_df = pd.read_csv("C:/Users/ralph/Bootcamp1/Final_Project/Data/Clean_data/Frontier_technology_readiness_index,annual.csv")

PC_data_df = pd.read_csv("C:/Users/ralph/Bootcamp1/Final_Project/Data/Clean_data/Productive_capacities_index,annual.csv")

WD_data_df = pd.read_csv("C:/Users/ralph/Bootcamp1/Final_Project/Data/Clean_data/World_development_indicators.csv")

summary_gdp_df = pd.read_csv("C:/Users/ralph/Bootcamp1/Final_Project/Data/Clean_data/summary_gdp_data.csv")

summary_gdp_df
# Out:
#      country_code      economy              region  years  tech_overall_index  \
# 0             AFG  Afghanistan          South Asia   2008            0.072075
# 1             AFG  Afghanistan          South Asia   2009            0.071051
# 2             AFG  Afghanistan          South Asia   2010            0.096194
# 3             AFG  Afghanistan          South Asia   2011            0.123014
# 4             AFG  Afghanistan          South Asia   2012            0.052903
# ...           ...          ...                 ...    ...                 ...
# 1700          ZWE     Zimbabwe  Sub-Saharan Africa   2014            0.076351
# 1701          ZWE     Zimbabwe  Sub-Saharan Africa   2015            0.151292
# 1702          ZWE     Zimbabwe  Sub-Saharan Africa   2016            0.136554
# 1703          ZWE     Zimbabwe  Sub-Saharan Africa   2017            0.135447
# 1704          ZWE     Zimbabwe  Sub-Saharan Africa   2018            0.132221
#
# ...

# %%
# Determine if there are any missing values in the FT_data

FT_data_df.count()
# Out:
# country_code           1872
# YEARS                  1872
# tech_overall_index     1872
#   ICT                  1872
#   skills               1872
# research_dev           1872
#   Industry_activity    1872
# finance_access         1872
# dtype: int64

# %%
FT_data_df.YEARS.nunique()
# Out:
# 12

# %%
# Determine if there are any missing values in the PC_data

PC_data_df.count()
# Out:
# country_code               1716
# YEARS                      1716
# productivity_over_index    1716
# human_capital              1716
# natural_capacity           1716
# energy                     1716
# transport                  1716
# info_comm_tech             1716
# institutions               1716
# private_sector             1716
# structural_change          1716
# dtype: int64

# %%
PC_data_df.YEARS.nunique()
# Out:
# 11

# %%
# Determine if there are any missing values in the WD_data

WD_data_df.count()
# Out:
# country_code                2166
# YEARS                       2166
# GDP_USdollars_millions      2166
# GDP_per_capita_Usdollars    2166
# dtype: int64

# %%
WD_data_df.YEARS.nunique()
# Out:
# 14

# %%
WD_data_df.head()
# Out:
#   country_code  YEARS  GDP_USdollars_millions  GDP_per_capita_Usdollars
# 0          AFG   2008             10236.90159                387.362338
# 1          AFG   2009             11595.13347                423.407102
# 2          AFG   2010             14698.88968                521.428191
# 3          AFG   2011             17350.69495                593.203248
# 4          AFG   2012             19136.49934                628.116539

# %%
# Summary_GDP shape

summary_gdp_df.shape
# Out:
# (1705, 21)

# %%
# Checking for nulls Summary_GDP

summary_gdp_df.isnull().sum()
# Out:
# country_code                0
# economy                     0
# region                      0
# years                       0
# tech_overall_index          0
# ict                         0
# skills                      0
# research_dev                0
# industry_activity           0
# finance_access              0
# gdp_usdollars_millions      0
# gdp_per_capita_usdollars    0
# productivity_over_index     0
# human_capital               0
# natural_capacity            0
# energy                      0
# transport                   0
# info_comm_tech              0
# institutions                0
# private_sector              0
# structural_change           0
# dtype: int64

# %%
# Summary_GDP info

summary_gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1705 entries, 0 to 1704
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country_code              1705 non-null   object
#  1   economy                   1705 non-null   object
#  2   region                    1705 non-null   object
#  3   years                     1705 non-null   int64
#  4   tech_overall_index        1705 non-null   float64
#  5   ict                       1705 non-null   float64
#  6   skills                    1705 non-null   float64
#  7   research_dev              1705 non-null   float64
#  8   industry_activity         1705 non-null   float64
#  9   finance_access            1705 non-null   float64
#  10  gdp_usdollars_millions    1705 non-null   float64
#  11  gdp_per_capita_usdollars  1705 non-null   float64
#  12  productivity_over_index   1705 non-null   float64
# ...

# %%
# Describing data in summary_gdp_df

summary_gdp_df.describe()
# Out:
#              years  tech_overall_index          ict       skills  \
# count  1705.000000         1705.000000  1705.000000  1705.000000
# mean   2013.000000            0.419375     0.384616     0.476225
# std       3.163205            0.275673     0.264665     0.241281
# min    2008.000000            0.000000     0.000000     0.000000
# 25%    2010.000000            0.187340     0.142554     0.278432
# 50%    2013.000000            0.370369     0.341626     0.473927
# 75%    2016.000000            0.621239     0.575599     0.664388
# max    2018.000000            1.000000     1.000000     1.000000
#
#        research_dev  industry_activity  finance_access  \
# count   1705.000000        1705.000000     1705.000000
# mean       0.243080           0.491360        0.597351
# std        0.242238           0.212027        0.205131
# min        0.000000           0.000000        0.000000
# 25%        0.046784           0.327310        0.463683
# ...

# %%
# Correlation Matrix for summary_gdp

summary_gdp_df.corr()
# Out:
#                              years  tech_overall_index       ict    skills  \
# years                     1.000000            0.064324  0.221652 -0.106611
# tech_overall_index        0.064324            1.000000  0.902185  0.891060
# ict                       0.221652            0.902185  1.000000  0.789502
# skills                   -0.106611            0.891060  0.789502  1.000000
# research_dev              0.089250            0.876278  0.715220  0.675896
# industry_activity         0.005721            0.805287  0.649551  0.605392
# finance_access           -0.008973            0.795964  0.673262  0.692127
# gdp_usdollars_millions    0.024652            0.376720  0.223911  0.216285
# gdp_per_capita_usdollars  0.015283            0.742318  0.701866  0.710308
# productivity_over_index   0.092237            0.932209  0.871884  0.882903
# human_capital             0.085051            0.930752  0.854474  0.887779
# ...
